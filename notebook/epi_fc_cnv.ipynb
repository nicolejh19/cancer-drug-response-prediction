# %% [markdown]
# This notebook uses episodic training with CNV data as input data.
#
# This uses AUROC when validating model during training and saving best model. TCGA is seen by model when training. There are 2 domain-specific modules, for cell-line and TCGA.
#
# This is an ablation study where the random classifier component of Epi-FCR is absent.

# %% [markdown]
# #### Imports

# %%
import pandas as pd
import numpy as np

# %%
import sys

sys.path.append("../../vae_zinb_reprn/")
sys.path.append("../src/")

# %%
import datetime
import logging
import time
import torch
import random

# %%
from EpiFCModel import ModelEpiFC

# %%
chosen_seed = 42
torch.manual_seed(chosen_seed)
random.seed(chosen_seed)
np.random.seed(chosen_seed)

# %%
torch.multiprocessing.set_sharing_strategy('file_system')

# %% [markdown]
# ### PACLITAXEL

# %%
best_parameters = {'audrc_threshold': 0.3201828394967454,
 'ldr': 0.4434139466696423,
 'lr': 0.22839922476988755,
 'weight_decay': 0.10803443440316346,
 'momentum': 0.3621663300280601,
 'step_size': 81,
 'loss_weight_epic': 6.176727204821433,
 'loss_weight_epif': 1.179668661228714,
 'loops_agg_warm': 70,
 'loops_train': 200,
 'loops_warm': 80,
 'warm_up_agg': 1,
 'hd': 2,
 'batch_size': 32,
 'test_every': 1,
 'ite_train_epi_c': 60,
 'ite_train_epi_f': 60,
 'bn_eval': 0,
 'seed': 42}

# %%
model_PACLITAXEL = ModelEpiFC('PACLITAXEL', 'cnv')
#  Unable to calculate AUROC for validation set 1
model_PACLITAXEL.get_results(best_parameters)
# Out:
# DomainSpecificNN(
#   (feature1): FeatModule(
#     (features): Sequential(
#       (0): Linear(in_features=324, out_features=256, bias=True)
#       (1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.4434139466696423, inplace=False)
#       (4): Linear(in_features=256, out_features=256, bias=True)
#       (5): Sigmoid()
#     )
#   )
#   (feature2): FeatModule(
#     (features): Sequential(
#       (0): Linear(in_features=324, out_features=256, bias=True)
#       (1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.4434139466696423, inplace=False)
#       (4): Linear(in_features=256, out_features=256, bias=True)
#       (5): Sigmoid()
#     )
#   )
#   (classifier1): ClassifierModule(
#     (pred): Sequential(
#       (0): Linear(in_features=256, out_features=1, bias=True)
#     )
#   )
#   (classifier2): ClassifierModule(
#     (pred): Sequential(
#       (0): Linear(in_features=256, out_features=1, bias=True)
#     )
#   )
# )
# DomainAGG(
#   (feature): FeatModule(
#     (features): Sequential(
#       (0): Linear(in_features=324, out_features=256, bias=True)
#       (1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.4434139466696423, inplace=False)
#       (4): Linear(in_features=256, out_features=256, bias=True)
#       (5): Sigmoid()
#     )
#   )
#   (classifier): ClassifierModule(
#     (pred): Sequential(
#       (0): Linear(in_features=256, out_features=1, bias=True)
#     )
#   )
# )
# flags: {'audrc_threshold': 0.3201828394967454, 'ldr': 0.4434139466696423, 'lr': 0.22839922476988755, 'weight_decay': 0.10803443440316346, 'momentum': 0.3621663300280601, 'step_size': 81, 'loss_weight_epic': 6.176727204821433, 'loss_weight_epif': 1.179668661228714, 'loops_agg_warm': 70, 'loops_train': 200, 'loops_warm': 80, 'warm_up_agg': 1, 'hd': 2, 'batch_size': 32, 'test_every': 1, 'ite_train_epi_c': 60, 'ite_train_epi_f': 60, 'bn_eval': 0, 'seed': 42}
# -------PACLITAXEL-------
# Threshold used for cell-line with PACLITAXEL: 0.3201828394967454
# cl train set size: 486
# tcga train set size: 65
# tcga validation set size: 17
# Threshold used for cell-line with PACLITAXEL: 0.3201828394967454
# cl test set size: 68
# pdx test set size: 8
# tcga test set size: 31
# Highest mean AUROC achieved during training: 0.9848484848484849
# Test set Idx 0 has only response [0]
# [0.60308886 0.623615   0.63142325 0.64156267 0.65437658 0.70515919]
# Test set Idx 1 has only response [0]
# [0.63683468 0.63805525 0.63870898 0.64090058 0.64205381 0.65329587]
# [0.62694257 0.63318515 0.63607031 0.64084631 0.64961344 0.66555208]
# /home/nicole/anaconda3/envs/druid/lib/python3.9/site-packages/sklearn/metrics/_ranking.py:877: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/nicole/anaconda3/envs/druid/lib/python3.9/site-packages/sklearn/metrics/_ranking.py:877: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#      dataset  length_dataset   value_counts   roc_auc      aupr
# 0  cell-line              68        {0: 68}       NaN -0.000000
# 0        PDX               8         {0: 8}       NaN -0.000000
# 0       TCGA              31  {1: 23, 0: 8}  0.777174  0.928405

# %%
model_PACLITAXEL.get_roc_pr_curves(best_parameters, False, 'tcga')

# %%
model_PACLITAXEL.get_train_set_results(best_parameters, False)
# Out:
# Threshold used for cell-line with PACLITAXEL: 0.3201828394967454
#      dataset  length_dataset    value_counts   roc_auc      aupr
# 0  cell-line             608  {0: 600, 1: 8}  0.483125  0.030658
# 0        PDX              35   {0: 30, 1: 5}  0.306667  0.133786
# 0       TCGA              82  {1: 53, 0: 29}  0.487313  0.611125

# %%
model_PACLITAXEL.plot_confusion_matrix(best_parameters, False, 'tcga', 0.5)
# Out:
# Distribution of Predictions by Model
# [0.62694257 0.63607031 0.64084631 0.64961344 0.66555208]
# TP: 23, FP: 8, TN: 0, FN: 0

# %% [markdown]
# ### CISPLATIN

# %%
best_parameters = {'audrc_threshold': 0.2905134599842131,
 'ldr': 0.08883102145045996,
 'lr': 0.13048349511809648,
 'weight_decay': 0.09680433155037463,
 'momentum': 0.6340746430680155,
 'step_size': 32,
 'loss_weight_epic': 4.956705323420465,
 'loss_weight_epif': 0.2631155541166663,
 'loops_agg_warm': 50,
 'warm_up_agg': 0,
 'ite_train_epi_c': 150,
 'ite_train_epi_f': 70,
 'hd': 1,
 'batch_size': 32,
 'loops_train': 400,
 'loops_warm': 150,
 'test_every': 1,
 'bn_eval': 0,
 'seed': 42}

# %%
model_CISPLATIN = ModelEpiFC('CISPLATIN', 'cnv')
#  Unable to calculate AUROC for validation set 1
model_CISPLATIN.get_results(best_parameters)
# Out:
# DomainSpecificNN(
#   (feature1): FeatModule(
#     (features): Sequential(
#       (0): Linear(in_features=324, out_features=512, bias=True)
#       (1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.08883102145045996, inplace=False)
#       (4): Linear(in_features=512, out_features=128, bias=True)
#       (5): Sigmoid()
#     )
#   )
#   (feature2): FeatModule(
#     (features): Sequential(
#       (0): Linear(in_features=324, out_features=512, bias=True)
#       (1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.08883102145045996, inplace=False)
#       (4): Linear(in_features=512, out_features=128, bias=True)
#       (5): Sigmoid()
#     )
#   )
#   (classifier1): ClassifierModule(
#     (pred): Sequential(
#       (0): Linear(in_features=128, out_features=1, bias=True)
#     )
#   )
#   (classifier2): ClassifierModule(
#     (pred): Sequential(
#       (0): Linear(in_features=128, out_features=1, bias=True)
#     )
#   )
# )
# DomainAGG(
#   (feature): FeatModule(
#     (features): Sequential(
#       (0): Linear(in_features=324, out_features=512, bias=True)
#       (1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.08883102145045996, inplace=False)
#       (4): Linear(in_features=512, out_features=128, bias=True)
#       (5): Sigmoid()
#     )
#   )
#   (classifier): ClassifierModule(
#     (pred): Sequential(
#       (0): Linear(in_features=128, out_features=1, bias=True)
#     )
#   )
# )
# flags: {'audrc_threshold': 0.2905134599842131, 'ldr': 0.08883102145045996, 'lr': 0.13048349511809648, 'weight_decay': 0.09680433155037463, 'momentum': 0.6340746430680155, 'step_size': 32, 'loss_weight_epic': 4.956705323420465, 'loss_weight_epif': 0.2631155541166663, 'loops_agg_warm': 50, 'warm_up_agg': 0, 'ite_train_epi_c': 150, 'ite_train_epi_f': 70, 'hd': 1, 'batch_size': 32, 'loops_train': 400, 'loops_warm': 150, 'test_every': 1, 'bn_eval': 0, 'seed': 42}
# -------CISPLATIN-------
# Threshold used for cell-line with CISPLATIN: 0.2905134599842131
# cl train set size: 386
# tcga train set size: 136
# tcga validation set size: 34
# Threshold used for cell-line with CISPLATIN: 0.2905134599842131
# cl test set size: 54
# pdx test set size: 0
# tcga test set size: 36
# Highest mean AUROC achieved during training: 0.7740384615384616
# [0.46765503 0.46866305 0.47046764 0.47429942 0.50413901 0.55655974]
# PDX test set not available
# [0.51772839 0.52165306 0.529467   0.53602523 0.54339749 0.56883872]
#      dataset  length_dataset   value_counts   roc_auc      aupr
# 0  cell-line              54  {0: 53, 1: 1}  0.830189  0.100000
# 0       TCGA              36  {1: 27, 0: 9}  0.736626  0.914759

# %%
model_CISPLATIN.get_roc_pr_curves(best_parameters, False, 'tcga')

# %%
model_CISPLATIN.get_train_set_results(best_parameters, False)
# Out:
# Threshold used for cell-line with CISPLATIN: 0.2905134599842131
# Test set Idx 1 has only response []
#      dataset  length_dataset     value_counts   roc_auc      aupr
# 0  cell-line             483   {0: 479, 1: 4}  0.809499  0.043900
# 0        PDX               0               {}       NaN       NaN
# 0       TCGA             170  {1: 130, 0: 40}  0.466635  0.733309

# %%
model_CISPLATIN.plot_confusion_matrix(best_parameters, False, 'tcga', 0.5)
# Out:
# Distribution of Predictions by Model
# [0.51772839 0.529467   0.53602523 0.54339749 0.56883872]
# TP: 27, FP: 9, TN: 0, FN: 0

# %% [markdown]
# ## 5-FLUOROURACIL

# %%
best_parameters = {'audrc_threshold': 0.27997513353824616,
 'ldr': 0.291043663918972,
 'lr': 0.26822978854179386,
 'weight_decay': 0.05419432163238525,
 'momentum': 0.2952832210063934,
 'step_size': 53,
 'loss_weight_epic': 5.455292284488678,
 'loss_weight_epif': 1.7492030262947083,
 'loops_agg_warm': 90,
 'ite_train_epi_f': 50,
 'hd': 1,
 'batch_size': 32,
 'loops_train': 200,
 'loops_warm': 100,
 'warm_up_agg': 0,
 'test_every': 1,
 'ite_train_epi_c': 100,
 'bn_eval': 0,
 'seed': 42}

# %%
model_5_FLUOROURACIL = ModelEpiFC('5-FLUOROURACIL', 'cnv')
#  Unable to calculate AUROC for validation set 1
model_5_FLUOROURACIL.get_results(best_parameters)
# Out:
# DomainSpecificNN(
#   (feature1): FeatModule(
#     (features): Sequential(
#       (0): Linear(in_features=324, out_features=512, bias=True)
#       (1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.291043663918972, inplace=False)
#       (4): Linear(in_features=512, out_features=128, bias=True)
#       (5): Sigmoid()
#     )
#   )
#   (feature2): FeatModule(
#     (features): Sequential(
#       (0): Linear(in_features=324, out_features=512, bias=True)
#       (1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.291043663918972, inplace=False)
#       (4): Linear(in_features=512, out_features=128, bias=True)
#       (5): Sigmoid()
#     )
#   )
#   (classifier1): ClassifierModule(
#     (pred): Sequential(
#       (0): Linear(in_features=128, out_features=1, bias=True)
#     )
#   )
#   (classifier2): ClassifierModule(
#     (pred): Sequential(
#       (0): Linear(in_features=128, out_features=1, bias=True)
#     )
#   )
# )
# DomainAGG(
#   (feature): FeatModule(
#     (features): Sequential(
#       (0): Linear(in_features=324, out_features=512, bias=True)
#       (1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.291043663918972, inplace=False)
#       (4): Linear(in_features=512, out_features=128, bias=True)
#       (5): Sigmoid()
#     )
#   )
#   (classifier): ClassifierModule(
#     (pred): Sequential(
#       (0): Linear(in_features=128, out_features=1, bias=True)
#     )
#   )
# )
# flags: {'audrc_threshold': 0.27997513353824616, 'ldr': 0.291043663918972, 'lr': 0.26822978854179386, 'weight_decay': 0.05419432163238525, 'momentum': 0.2952832210063934, 'step_size': 53, 'loss_weight_epic': 5.455292284488678, 'loss_weight_epif': 1.7492030262947083, 'loops_agg_warm': 90, 'ite_train_epi_f': 50, 'hd': 1, 'batch_size': 32, 'loops_train': 200, 'loops_warm': 100, 'warm_up_agg': 0, 'test_every': 1, 'ite_train_epi_c': 100, 'bn_eval': 0, 'seed': 42}
# -------5-FLUOROURACIL-------
# Threshold used for cell-line with 5-FLUOROURACIL: 0.27997513353824616
# cl train set size: 422
# tcga train set size: 83
# tcga validation set size: 21
# Threshold used for cell-line with 5-FLUOROURACIL: 0.27997513353824616
# cl test set size: 61
# pdx test set size: 0
# tcga test set size: 21
# Highest mean AUROC achieved during training: 0.7403846153846154
# Test set Idx 0 has only response [0]
# [3.73871046e-07 8.00090788e-07 2.91463857e-06 9.44093608e-06
#  2.29228954e-05 1.20424942e-04]
# PDX test set not available
# [3.02173447e-07 4.39524740e-07 6.80128721e-07 9.06986486e-07
#  1.11674797e-06 9.51236780e-06]
# /home/nicole/anaconda3/envs/druid/lib/python3.9/site-packages/sklearn/metrics/_ranking.py:877: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#      dataset  length_dataset   value_counts   roc_auc      aupr
# 0  cell-line              61        {0: 61}       NaN -0.000000
# 0       TCGA              21  {1: 17, 0: 4}  0.757353  0.927978

# %%
model_5_FLUOROURACIL.get_roc_pr_curves(best_parameters, False, 'tcga')

# %%
model_5_FLUOROURACIL.get_train_set_results(best_parameters, False)
# Out:
# Threshold used for cell-line with 5-FLUOROURACIL: 0.27997513353824616
# Test set Idx 0 has only response [0]
# Test set Idx 1 has only response []
#      dataset  length_dataset    value_counts   roc_auc      aupr
# 0  cell-line             528        {0: 528}       NaN       NaN
# 0        PDX               0              {}       NaN       NaN
# 0       TCGA             104  {1: 65, 0: 39}  0.680276  0.709443

# %%
model_5_FLUOROURACIL.plot_confusion_matrix(best_parameters, False, 'tcga', 0.5)
# Out:
# Distribution of Predictions by Model
# [3.02173447e-07 6.80128721e-07 9.06986486e-07 1.11674797e-06
#  9.51236780e-06]
# TP: 0, FP: 0, TN: 4, FN: 17

# %% [markdown]
# ## CYCLOPHOSPHAMIDE

# %%
best_parameters = {'audrc_threshold': 0.3499005341529846,
 'ldr': 0.20313099175691607,
 'lr': 0.2952170395851135,
 'weight_decay': 0.048388643264770506,
 'momentum': 0.6316993260383607,
 'step_size': 36,
 'loss_weight_epic': 3.187045991420746,
 'loss_weight_epif': 5.244421184062958,
 'loops_agg_warm': 60,
 'loops_train': 400,
 'loops_warm': 80,
 'warm_up_agg': 0,
 'ite_train_epi_c': 0,
 'ite_train_epi_f': 100,
 'hd': 4,
 'batch_size': 64,
 'test_every': 1,
 'bn_eval': 0,
 'seed': 42}

# %%
model_CYCLOPHOSPHAMIDE = ModelEpiFC('CYCLOPHOSPHAMIDE', 'cnv')
#  Unable to calculate AUROC for validation set 1
model_CYCLOPHOSPHAMIDE.get_results(best_parameters)
# Out:
# DomainSpecificNN(
#   (feature1): FeatModule(
#     (features): Sequential(
#       (0): Linear(in_features=324, out_features=64, bias=True)
#       (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.20313099175691607, inplace=False)
#       (4): Linear(in_features=64, out_features=64, bias=True)
#       (5): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (6): ReLU()
#       (7): Dropout(p=0.20313099175691607, inplace=False)
#       (8): Linear(in_features=64, out_features=64, bias=True)
#       (9): Sigmoid()
#     )
#   )
#   (feature2): FeatModule(
#     (features): Sequential(
#       (0): Linear(in_features=324, out_features=64, bias=True)
#       (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.20313099175691607, inplace=False)
#       (4): Linear(in_features=64, out_features=64, bias=True)
#       (5): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (6): ReLU()
#       (7): Dropout(p=0.20313099175691607, inplace=False)
#       (8): Linear(in_features=64, out_features=64, bias=True)
#       (9): Sigmoid()
#     )
#   )
#   (classifier1): ClassifierModule(
#     (pred): Sequential(
#       (0): Linear(in_features=64, out_features=1, bias=True)
#     )
#   )
#   (classifier2): ClassifierModule(
#     (pred): Sequential(
#       (0): Linear(in_features=64, out_features=1, bias=True)
#     )
#   )
# )
# DomainAGG(
#   (feature): FeatModule(
#     (features): Sequential(
#       (0): Linear(in_features=324, out_features=64, bias=True)
#       (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.20313099175691607, inplace=False)
#       (4): Linear(in_features=64, out_features=64, bias=True)
#       (5): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (6): ReLU()
#       (7): Dropout(p=0.20313099175691607, inplace=False)
#       (8): Linear(in_features=64, out_features=64, bias=True)
#       (9): Sigmoid()
#     )
#   )
#   (classifier): ClassifierModule(
#     (pred): Sequential(
#       (0): Linear(in_features=64, out_features=1, bias=True)
#     )
#   )
# )
# flags: {'audrc_threshold': 0.3499005341529846, 'ldr': 0.20313099175691607, 'lr': 0.2952170395851135, 'weight_decay': 0.048388643264770506, 'momentum': 0.6316993260383607, 'step_size': 36, 'loss_weight_epic': 3.187045991420746, 'loss_weight_epif': 5.244421184062958, 'loops_agg_warm': 60, 'loops_train': 400, 'loops_warm': 80, 'warm_up_agg': 0, 'ite_train_epi_c': 0, 'ite_train_epi_f': 100, 'hd': 4, 'batch_size': 64, 'test_every': 1, 'bn_eval': 0, 'seed': 42}
# -------CYCLOPHOSPHAMIDE-------
# Threshold used for cell-line with CYCLOPHOSPHAMIDE: 0.3499005341529846
# cl train set size: 463
# tcga train set size: 40
# tcga validation set size: 10
# Threshold used for cell-line with CYCLOPHOSPHAMIDE: 0.3499005341529846
# cl test set size: 66
# pdx test set size: 0
# tcga test set size: 19
# Highest mean AUROC achieved during training: 1.0
# [7.03208279e-05 1.13876569e-04 2.11088878e-04 7.20434444e-04
#  1.17519675e-03 3.91659793e-03]
# PDX test set not available
# [6.31079965e-05 6.51671886e-05 6.94501687e-05 1.10826026e-04
#  1.81817843e-04 3.10473144e-04]
#      dataset  length_dataset   value_counts   roc_auc      aupr
# 0  cell-line              66  {0: 65, 1: 1}  0.215385  0.019231
# 0       TCGA              19  {1: 17, 0: 2}  0.764706  0.969121

# %%
model_CYCLOPHOSPHAMIDE.get_roc_pr_curves(best_parameters, False, 'tcga')

# %%
model_CYCLOPHOSPHAMIDE.get_train_set_results(best_parameters, False)
# Out:
# Threshold used for cell-line with CYCLOPHOSPHAMIDE: 0.3499005341529846
# Test set Idx 1 has only response []
#      dataset  length_dataset     value_counts   roc_auc      aupr
# 0  cell-line             579  {0: 567, 1: 12}  0.172399  0.032884
# 0        PDX               0               {}       NaN       NaN
# 0       TCGA              50    {1: 47, 0: 3}  0.283688  0.878042

# %%
model_CYCLOPHOSPHAMIDE.plot_confusion_matrix(best_parameters, False, 'tcga', 0.5)
# Out:
# Distribution of Predictions by Model
# [6.31079965e-05 6.94501687e-05 1.10826026e-04 1.81817843e-04
#  3.10473144e-04]
# TP: 0, FP: 0, TN: 2, FN: 17

# %% [markdown]
# ## GEMCITABINE

# %%
best_parameters = {'audrc_threshold': 0.4392632572680865,
 'ldr': 0.37983929676493033,
 'lr': 0.2478175840975923,
 'weight_decay': 0.00960898782154241,
 'momentum': 0.49396765293540823,
 'step_size': 27,
 'loss_weight_epic': 5.165219140325036,
 'loss_weight_epif': 5.44144359984511,
 'loops_agg_warm': 70,
 'loops_train': 200,
 'loops_warm': 100,
 'warm_up_agg': 0,
 'ite_train_epi_c': 70,
 'ite_train_epi_f': 60,
 'hd': 2,
 'batch_size': 32,
 'test_every': 1,
 'bn_eval': 0,
 'seed': 42}

# %%
model_GEMCITABINE = ModelEpiFC('GEMCITABINE', 'cnv')
#  Unable to calculate AUROC for validation set 1
model_GEMCITABINE.get_results(best_parameters)
# Out:
# DomainSpecificNN(
#   (feature1): FeatModule(
#     (features): Sequential(
#       (0): Linear(in_features=324, out_features=256, bias=True)
#       (1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.37983929676493033, inplace=False)
#       (4): Linear(in_features=256, out_features=256, bias=True)
#       (5): Sigmoid()
#     )
#   )
#   (feature2): FeatModule(
#     (features): Sequential(
#       (0): Linear(in_features=324, out_features=256, bias=True)
#       (1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.37983929676493033, inplace=False)
#       (4): Linear(in_features=256, out_features=256, bias=True)
#       (5): Sigmoid()
#     )
#   )
#   (classifier1): ClassifierModule(
#     (pred): Sequential(
#       (0): Linear(in_features=256, out_features=1, bias=True)
#     )
#   )
#   (classifier2): ClassifierModule(
#     (pred): Sequential(
#       (0): Linear(in_features=256, out_features=1, bias=True)
#     )
#   )
# )
# DomainAGG(
#   (feature): FeatModule(
#     (features): Sequential(
#       (0): Linear(in_features=324, out_features=256, bias=True)
#       (1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.37983929676493033, inplace=False)
#       (4): Linear(in_features=256, out_features=256, bias=True)
#       (5): Sigmoid()
#     )
#   )
#   (classifier): ClassifierModule(
#     (pred): Sequential(
#       (0): Linear(in_features=256, out_features=1, bias=True)
#     )
#   )
# )
# flags: {'audrc_threshold': 0.4392632572680865, 'ldr': 0.37983929676493033, 'lr': 0.2478175840975923, 'weight_decay': 0.00960898782154241, 'momentum': 0.49396765293540823, 'step_size': 27, 'loss_weight_epic': 5.165219140325036, 'loss_weight_epif': 5.44144359984511, 'loops_agg_warm': 70, 'loops_train': 200, 'loops_warm': 100, 'warm_up_agg': 0, 'ite_train_epi_c': 70, 'ite_train_epi_f': 60, 'hd': 2, 'batch_size': 32, 'test_every': 1, 'bn_eval': 0, 'seed': 42}
# -------GEMCITABINE-------
# Threshold used for cell-line with GEMCITABINE: 0.4392632572680865
# cl train set size: 386
# tcga train set size: 35
# tcga validation set size: 9
# Threshold used for cell-line with GEMCITABINE: 0.4392632572680865
# cl test set size: 54
# pdx test set size: 0
# tcga test set size: 18
# Highest mean AUROC achieved during training: 0.9722222222222223
# Test set Idx 0 has only response [0]
# [0.15472233 0.20575725 0.24267583 0.27983099 0.30214065 0.4156186 ]
# PDX test set not available
# [0.2974408  0.30261675 0.31547958 0.33637579 0.40732896 0.95693982]
# /home/nicole/anaconda3/envs/druid/lib/python3.9/site-packages/sklearn/metrics/_ranking.py:877: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#      dataset  length_dataset  value_counts   roc_auc      aupr
# 0  cell-line              54       {0: 54}       NaN -0.000000
# 0       TCGA              18  {0: 9, 1: 9}  0.604938  0.754338

# %%
model_GEMCITABINE.get_roc_pr_curves(best_parameters, False, 'tcga')

# %%
model_GEMCITABINE.get_train_set_results(best_parameters, False)
# Out:
# Threshold used for cell-line with GEMCITABINE: 0.4392632572680865
# Test set Idx 0 has only response [0]
# Test set Idx 1 has only response []
#      dataset  length_dataset    value_counts   roc_auc      aupr
# 0  cell-line             483        {0: 483}       NaN       NaN
# 0        PDX               0              {}       NaN       NaN
# 0       TCGA              44  {1: 27, 0: 17}  0.449891  0.558694

# %%
model_GEMCITABINE.plot_confusion_matrix(best_parameters, False, 'tcga', 0.5)
# Out:
# Distribution of Predictions by Model
# [0.2974408  0.31547958 0.33637579 0.40732896 0.95693982]
# TP: 2, FP: 0, TN: 9, FN: 7
