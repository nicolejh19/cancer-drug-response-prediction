# %% [markdown]
# This notebook uses episodic training with raw mutation data as input data.
#
# This uses AUROC when validating model during training and saving best model. TCGA is seen by model when training. There are 2 domain-specific modules, for cell-line and TCGA.

# %% [markdown]
# #### Imports

# %%
import pandas as pd
import numpy as np

# %%
import sys
sys.path.append("../src/")

# %%
import datetime
import logging
import time
import torch
import random

# %%
from EpiFCRModel import ModelEpiFCR

# %%
chosen_seed = 42
torch.manual_seed(chosen_seed)
random.seed(chosen_seed)
np.random.seed(chosen_seed)

# %%
torch.multiprocessing.set_sharing_strategy('file_system')

# %% [markdown]
# ### PACLITAXEL

# %%
best_parameters = {'audrc_threshold': 0.26647883534298583,
 'ldr': 0.4551569904222381,
 'lr': 0.43412444265602357,
 'weight_decay': 0.01765619910920584,
 'momentum': 0.8535158190785519,
 'step_size': 29,
 'loss_weight_epic': 1.266350619733658,
 'loss_weight_epif': 3.4153421051191364,
 'loss_weight_epir': 1.5879123410502654,
 'hd': 3,
 'batch_size': 32,
 'loops_agg_warm': 60,
 'loops_train': 600,
 'loops_warm': 100,
 'warm_up_agg': 1,
 'test_every': 1,
 'ite_train_epi_c': 0,
 'ite_train_epi_f': 90,
 'bn_eval': 0,
 'seed': 42}

# %%
model_PACLITAXEL = ModelEpiFCR('PACLITAXEL', 'mutation')
model_PACLITAXEL.get_results(best_parameters)
# Out:
# DomainSpecificNN(
#   (feature1): FeatModule(
#     (features): Sequential(
#       (0): Linear(in_features=324, out_features=128, bias=True)
#       (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.4551569904222381, inplace=False)
#       (4): Linear(in_features=128, out_features=128, bias=True)
#       (5): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (6): ReLU()
#       (7): Dropout(p=0.4551569904222381, inplace=False)
#       (8): Linear(in_features=128, out_features=128, bias=True)
#       (9): Sigmoid()
#     )
#   )
#   (feature2): FeatModule(
#     (features): Sequential(
#       (0): Linear(in_features=324, out_features=128, bias=True)
#       (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.4551569904222381, inplace=False)
#       (4): Linear(in_features=128, out_features=128, bias=True)
#       (5): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (6): ReLU()
#       (7): Dropout(p=0.4551569904222381, inplace=False)
#       (8): Linear(in_features=128, out_features=128, bias=True)
#       (9): Sigmoid()
#     )
#   )
#   (classifier1): ClassifierModule(
#     (pred): Sequential(
#       (0): Linear(in_features=128, out_features=1, bias=True)
#     )
#   )
#   (classifier2): ClassifierModule(
#     (pred): Sequential(
#       (0): Linear(in_features=128, out_features=1, bias=True)
#     )
#   )
# )
# DomainAGG(
#   (feature): FeatModule(
#     (features): Sequential(
#       (0): Linear(in_features=324, out_features=128, bias=True)
#       (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.4551569904222381, inplace=False)
#       (4): Linear(in_features=128, out_features=128, bias=True)
#       (5): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (6): ReLU()
#       (7): Dropout(p=0.4551569904222381, inplace=False)
#       (8): Linear(in_features=128, out_features=128, bias=True)
#       (9): Sigmoid()
#     )
#   )
#   (classifier): ClassifierModule(
#     (pred): Sequential(
#       (0): Linear(in_features=128, out_features=1, bias=True)
#     )
#   )
#   (classifierrand): ClassifierModule(
#     (pred): Sequential(
#       (0): Linear(in_features=128, out_features=1, bias=True)
#     )
#   )
# )
# flags: {'audrc_threshold': 0.26647883534298583, 'ldr': 0.4551569904222381, 'lr': 0.43412444265602357, 'weight_decay': 0.01765619910920584, 'momentum': 0.8535158190785519, 'step_size': 29, 'loss_weight_epic': 1.266350619733658, 'loss_weight_epif': 3.4153421051191364, 'loss_weight_epir': 1.5879123410502654, 'hd': 3, 'batch_size': 32, 'loops_agg_warm': 60, 'loops_train': 600, 'loops_warm': 100, 'warm_up_agg': 1, 'test_every': 1, 'ite_train_epi_c': 0, 'ite_train_epi_f': 90, 'bn_eval': 0, 'seed': 42}
# -------PACLITAXEL-------
# Threshold used for cell-line with PACLITAXEL: 0.26647883534298583
# cl train set size: 486
# tcga train set size: 65
# tcga validation set size: 17
# Threshold used for cell-line with PACLITAXEL: 0.26647883534298583
# cl test set size: 68
# pdx test set size: 8
# tcga test set size: 31
# Highest mean AUROC achieved during training: 0.5909090909090908
# Test set Idx 0 has only response [0]
# [0.1914572  0.28847233 0.40593535 0.57058677 0.63664615 0.70953548]
# Test set Idx 1 has only response [0]
# [0.21982767 0.25904057 0.32731996 0.49153277 0.54039395 0.69024438]
# [0.20102766 0.34610668 0.41742437 0.51758254 0.57822001 0.70483893]
# /home/nicole/anaconda3/envs/druid/lib/python3.9/site-packages/sklearn/metrics/_ranking.py:877: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# /home/nicole/anaconda3/envs/druid/lib/python3.9/site-packages/sklearn/metrics/_ranking.py:877: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#      dataset  length_dataset   value_counts   roc_auc      aupr
# 0  cell-line              68        {0: 68}       NaN -0.000000
# 0        PDX               8         {0: 8}       NaN -0.000000
# 0       TCGA              31  {1: 23, 0: 8}  0.804348  0.918305

# %%
model_PACLITAXEL.get_roc_pr_curves(best_parameters, False, 'tcga')

# %%
model_PACLITAXEL.get_train_set_results(best_parameters, False)
# Out:
# Threshold used for cell-line with PACLITAXEL: 0.26647883534298583
#      dataset  length_dataset    value_counts   roc_auc      aupr
# 0  cell-line             608  {0: 605, 1: 3}  0.766942  0.038567
# 0        PDX              35   {0: 30, 1: 5}  0.546667  0.208028
# 0       TCGA              82  {1: 53, 0: 29}  0.940794  0.951260

# %%
model_PACLITAXEL.plot_confusion_matrix(best_parameters, False, 'tcga', 0.5)
# Out:
# Distribution of Predictions by Model
# [0.20102766 0.41742437 0.51758254 0.57822001 0.70483893]
# TP: 15, FP: 2, TN: 6, FN: 8

# %% [markdown]
# ### CISPLATIN

# %%
best_parameters = {'audrc_threshold': 0.40414191662586757,
 'ldr': 0.21895781468537504,
 'lr': 0.33926660391117197,
 'weight_decay': 0.0556100120459949,
 'momentum': 0.30873562347872585,
 'step_size': 80,
 'loss_weight_epic': 5.72643781678802,
 'loss_weight_epif': 0.1825457475121278,
 'loss_weight_epir': 3.7255190121808806,
 'loops_agg_warm': 50,
 'loops_train': 250,
 'loops_warm': 70,
 'warm_up_agg': 0,
 'ite_train_epi_c': 0,
 'ite_train_epi_f': 50,
 'hd': 3,
 'batch_size': 32,
 'test_every': 1,
 'bn_eval': 0,
 'seed': 42}

# %%
model_CISPLATIN = ModelEpiFCR('CISPLATIN', 'mutation')
#  Unable to calculate AUROC for validation set 1
model_CISPLATIN.get_results(best_parameters)
# Out:
# DomainSpecificNN(
#   (feature1): FeatModule(
#     (features): Sequential(
#       (0): Linear(in_features=324, out_features=128, bias=True)
#       (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.21895781468537504, inplace=False)
#       (4): Linear(in_features=128, out_features=128, bias=True)
#       (5): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (6): ReLU()
#       (7): Dropout(p=0.21895781468537504, inplace=False)
#       (8): Linear(in_features=128, out_features=128, bias=True)
#       (9): Sigmoid()
#     )
#   )
#   (feature2): FeatModule(
#     (features): Sequential(
#       (0): Linear(in_features=324, out_features=128, bias=True)
#       (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.21895781468537504, inplace=False)
#       (4): Linear(in_features=128, out_features=128, bias=True)
#       (5): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (6): ReLU()
#       (7): Dropout(p=0.21895781468537504, inplace=False)
#       (8): Linear(in_features=128, out_features=128, bias=True)
#       (9): Sigmoid()
#     )
#   )
#   (classifier1): ClassifierModule(
#     (pred): Sequential(
#       (0): Linear(in_features=128, out_features=1, bias=True)
#     )
#   )
#   (classifier2): ClassifierModule(
#     (pred): Sequential(
#       (0): Linear(in_features=128, out_features=1, bias=True)
#     )
#   )
# )
# DomainAGG(
#   (feature): FeatModule(
#     (features): Sequential(
#       (0): Linear(in_features=324, out_features=128, bias=True)
#       (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.21895781468537504, inplace=False)
#       (4): Linear(in_features=128, out_features=128, bias=True)
#       (5): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (6): ReLU()
#       (7): Dropout(p=0.21895781468537504, inplace=False)
#       (8): Linear(in_features=128, out_features=128, bias=True)
#       (9): Sigmoid()
#     )
#   )
#   (classifier): ClassifierModule(
#     (pred): Sequential(
#       (0): Linear(in_features=128, out_features=1, bias=True)
#     )
#   )
#   (classifierrand): ClassifierModule(
#     (pred): Sequential(
#       (0): Linear(in_features=128, out_features=1, bias=True)
#     )
#   )
# )
# flags: {'audrc_threshold': 0.40414191662586757, 'ldr': 0.21895781468537504, 'lr': 0.33926660391117197, 'weight_decay': 0.0556100120459949, 'momentum': 0.30873562347872585, 'step_size': 80, 'loss_weight_epic': 5.72643781678802, 'loss_weight_epif': 0.1825457475121278, 'loss_weight_epir': 3.7255190121808806, 'loops_agg_warm': 50, 'loops_train': 250, 'loops_warm': 70, 'warm_up_agg': 0, 'ite_train_epi_c': 0, 'ite_train_epi_f': 50, 'hd': 3, 'batch_size': 32, 'test_every': 1, 'bn_eval': 0, 'seed': 42}
# -------CISPLATIN-------
# Threshold used for cell-line with CISPLATIN: 0.40414191662586757
# cl train set size: 386
# tcga train set size: 136
# tcga validation set size: 34
# Threshold used for cell-line with CISPLATIN: 0.40414191662586757
# cl test set size: 54
# pdx test set size: 0
# tcga test set size: 36
# Highest mean AUROC achieved during training: 0.8846153846153846
# [0.9891572  0.99196176 0.99273895 0.99358845 0.99486697 0.99625659]
# PDX test set not available
# [0.98971903 0.99173427 0.99247135 0.99319667 0.99400334 0.99579155]
#      dataset  length_dataset   value_counts   roc_auc      aupr
# 0  cell-line              54  {0: 50, 1: 4}  0.560000  0.097208
# 0       TCGA              36  {1: 27, 0: 9}  0.687243  0.899814

# %%
model_CISPLATIN.get_roc_pr_curves(best_parameters, False, 'tcga')

# %%
model_CISPLATIN.get_train_set_results(best_parameters, False)
# Out:
# Threshold used for cell-line with CISPLATIN: 0.40414191662586757
# Test set Idx 1 has only response []
#      dataset  length_dataset     value_counts   roc_auc      aupr
# 0  cell-line             483  {0: 471, 1: 12}  0.617215  0.043402
# 0        PDX               0               {}       NaN       NaN
# 0       TCGA             170  {1: 130, 0: 40}  0.539519  0.788558

# %%
model_CISPLATIN.plot_confusion_matrix(best_parameters, False, 'tcga', 0.5)
# Out:
# Distribution of Predictions by Model
# [0.98971903 0.99247135 0.99319667 0.99400334 0.99579155]
# TP: 27, FP: 9, TN: 0, FN: 0

# %% [markdown]
# ## 5-FLUOROURACIL

# %%
best_parameters = {'audrc_threshold': 0.2899751335382461,
 'ldr': 0.32104366391897204,
 'lr': 0.028229788541793824,
 'weight_decay': 0.06419432163238525,
 'momentum': 0.5752832210063934,
 'step_size': 30,
 'loss_weight_epic': 6.455292284488678,
 'loss_weight_epif': 2.7492030262947083,
 'loss_weight_epir': 4.221074134111404,
 'hd': 4,
 'batch_size': 32,
 'loops_agg_warm': 80,
 'loops_train': 300,
 'loops_warm': 80,
 'warm_up_agg': 0,
 'test_every': 1,
 'ite_train_epi_c': 0,
 'ite_train_epi_f': 90,
 'bn_eval': 0,
 'seed': 42}

# %%
model_5_FLUOROURACIL = ModelEpiFCR('5-FLUOROURACIL', 'mutation')
#  Unable to calculate AUROC for validation set 1
model_5_FLUOROURACIL.get_results(best_parameters)
# Out:
# DomainSpecificNN(
#   (feature1): FeatModule(
#     (features): Sequential(
#       (0): Linear(in_features=324, out_features=64, bias=True)
#       (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.32104366391897204, inplace=False)
#       (4): Linear(in_features=64, out_features=64, bias=True)
#       (5): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (6): ReLU()
#       (7): Dropout(p=0.32104366391897204, inplace=False)
#       (8): Linear(in_features=64, out_features=64, bias=True)
#       (9): Sigmoid()
#     )
#   )
#   (feature2): FeatModule(
#     (features): Sequential(
#       (0): Linear(in_features=324, out_features=64, bias=True)
#       (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.32104366391897204, inplace=False)
#       (4): Linear(in_features=64, out_features=64, bias=True)
#       (5): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (6): ReLU()
#       (7): Dropout(p=0.32104366391897204, inplace=False)
#       (8): Linear(in_features=64, out_features=64, bias=True)
#       (9): Sigmoid()
#     )
#   )
#   (classifier1): ClassifierModule(
#     (pred): Sequential(
#       (0): Linear(in_features=64, out_features=1, bias=True)
#     )
#   )
#   (classifier2): ClassifierModule(
#     (pred): Sequential(
#       (0): Linear(in_features=64, out_features=1, bias=True)
#     )
#   )
# )
# DomainAGG(
#   (feature): FeatModule(
#     (features): Sequential(
#       (0): Linear(in_features=324, out_features=64, bias=True)
#       (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.32104366391897204, inplace=False)
#       (4): Linear(in_features=64, out_features=64, bias=True)
#       (5): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (6): ReLU()
#       (7): Dropout(p=0.32104366391897204, inplace=False)
#       (8): Linear(in_features=64, out_features=64, bias=True)
#       (9): Sigmoid()
#     )
#   )
#   (classifier): ClassifierModule(
#     (pred): Sequential(
#       (0): Linear(in_features=64, out_features=1, bias=True)
#     )
#   )
#   (classifierrand): ClassifierModule(
#     (pred): Sequential(
#       (0): Linear(in_features=64, out_features=1, bias=True)
#     )
#   )
# )
# flags: {'audrc_threshold': 0.2899751335382461, 'ldr': 0.32104366391897204, 'lr': 0.028229788541793824, 'weight_decay': 0.06419432163238525, 'momentum': 0.5752832210063934, 'step_size': 30, 'loss_weight_epic': 6.455292284488678, 'loss_weight_epif': 2.7492030262947083, 'loss_weight_epir': 4.221074134111404, 'hd': 4, 'batch_size': 32, 'loops_agg_warm': 80, 'loops_train': 300, 'loops_warm': 80, 'warm_up_agg': 0, 'test_every': 1, 'ite_train_epi_c': 0, 'ite_train_epi_f': 90, 'bn_eval': 0, 'seed': 42}
# -------5-FLUOROURACIL-------
# Threshold used for cell-line with 5-FLUOROURACIL: 0.2899751335382461
# cl train set size: 422
# tcga train set size: 83
# tcga validation set size: 21
# Threshold used for cell-line with 5-FLUOROURACIL: 0.2899751335382461
# cl test set size: 61
# pdx test set size: 0
# tcga test set size: 21
# Highest mean AUROC achieved during training: 0.6346153846153846
# Test set Idx 0 has only response [0]
# [0.49889696 0.4991402  0.49952623 0.49982721 0.50020391 0.50341737]
# PDX test set not available
# [0.49887067 0.49904588 0.49922112 0.49961948 0.49972758 0.49997139]
# /home/nicole/anaconda3/envs/druid/lib/python3.9/site-packages/sklearn/metrics/_ranking.py:877: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#      dataset  length_dataset   value_counts   roc_auc      aupr
# 0  cell-line              61        {0: 61}       NaN -0.000000
# 0       TCGA              21  {1: 17, 0: 4}  0.838235  0.957734

# %%
model_5_FLUOROURACIL.get_roc_pr_curves(best_parameters, False, 'tcga')

# %%
model_5_FLUOROURACIL.get_train_set_results(best_parameters, False)
# Out:
# Threshold used for cell-line with 5-FLUOROURACIL: 0.2899751335382461
# Test set Idx 0 has only response [0]
# Test set Idx 1 has only response []
#      dataset  length_dataset    value_counts   roc_auc      aupr
# 0  cell-line             528        {0: 528}       NaN       NaN
# 0        PDX               0              {}       NaN       NaN
# 0       TCGA             104  {1: 65, 0: 39}  0.554241  0.702676

# %%
model_5_FLUOROURACIL.plot_confusion_matrix(best_parameters, False, 'tcga', 0.5)
# Out:
# Distribution of Predictions by Model
# [0.49887067 0.49922112 0.49961948 0.49972758 0.49997139]
# TP: 0, FP: 0, TN: 4, FN: 17

# %% [markdown]
# ## CYCLOPHOSPHAMIDE

# %%
best_parameters = {'audrc_threshold': 0.49937833845615387,
 'ldr': 0.07157617121934891,
 'batch_size': 128,
 'lr': 0.21261892080307007,
 'weight_decay': 0.05283692684292794,
 'momentum': 0.050616636872291565,
 'step_size': 51,
 'loss_weight_epic': 5.244421184062958,
 'loss_weight_epif': 1.547518938779831,
 'loss_weight_epir': 4.323888599872589,
 'loops_agg_warm': 100,
 'loops_train': 250,
 'loops_warm': 50,
 'warm_up_agg': 1,
 'ite_train_epi_c': 150,
 'ite_train_epi_f': 150,
 'hd': 2,
 'test_every': 1,
 'bn_eval': 0,
 'seed': 42}

# %%
model_CYCLOPHOSPHAMIDE = ModelEpiFCR('CYCLOPHOSPHAMIDE', 'mutation')
#  Unable to calculate AUROC for validation set 1
model_CYCLOPHOSPHAMIDE.get_results(best_parameters)
# Out:
# DomainSpecificNN(
#   (feature1): FeatModule(
#     (features): Sequential(
#       (0): Linear(in_features=324, out_features=256, bias=True)
#       (1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.07157617121934891, inplace=False)
#       (4): Linear(in_features=256, out_features=256, bias=True)
#       (5): Sigmoid()
#     )
#   )
#   (feature2): FeatModule(
#     (features): Sequential(
#       (0): Linear(in_features=324, out_features=256, bias=True)
#       (1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.07157617121934891, inplace=False)
#       (4): Linear(in_features=256, out_features=256, bias=True)
#       (5): Sigmoid()
#     )
#   )
#   (classifier1): ClassifierModule(
#     (pred): Sequential(
#       (0): Linear(in_features=256, out_features=1, bias=True)
#     )
#   )
#   (classifier2): ClassifierModule(
#     (pred): Sequential(
#       (0): Linear(in_features=256, out_features=1, bias=True)
#     )
#   )
# )
# DomainAGG(
#   (feature): FeatModule(
#     (features): Sequential(
#       (0): Linear(in_features=324, out_features=256, bias=True)
#       (1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.07157617121934891, inplace=False)
#       (4): Linear(in_features=256, out_features=256, bias=True)
#       (5): Sigmoid()
#     )
#   )
#   (classifier): ClassifierModule(
#     (pred): Sequential(
#       (0): Linear(in_features=256, out_features=1, bias=True)
#     )
#   )
#   (classifierrand): ClassifierModule(
#     (pred): Sequential(
#       (0): Linear(in_features=256, out_features=1, bias=True)
#     )
#   )
# )
# flags: {'audrc_threshold': 0.49937833845615387, 'ldr': 0.07157617121934891, 'batch_size': 128, 'lr': 0.21261892080307007, 'weight_decay': 0.05283692684292794, 'momentum': 0.050616636872291565, 'step_size': 51, 'loss_weight_epic': 5.244421184062958, 'loss_weight_epif': 1.547518938779831, 'loss_weight_epir': 4.323888599872589, 'loops_agg_warm': 100, 'loops_train': 250, 'loops_warm': 50, 'warm_up_agg': 1, 'ite_train_epi_c': 150, 'ite_train_epi_f': 150, 'hd': 2, 'test_every': 1, 'bn_eval': 0, 'seed': 42}
# -------CYCLOPHOSPHAMIDE-------
# Threshold used for cell-line with CYCLOPHOSPHAMIDE: 0.49937833845615387
# cl train set size: 463
# tcga train set size: 40
# tcga validation set size: 10
# Threshold used for cell-line with CYCLOPHOSPHAMIDE: 0.49937833845615387
# cl test set size: 66
# pdx test set size: 0
# tcga test set size: 19
# Highest mean AUROC achieved during training: 1.0
# [0.72197801 0.73087606 0.74100399 0.74685121 0.75194684 0.76304233]
# PDX test set not available
# [0.74969923 0.75472081 0.76011512 0.76188463 0.76561823 0.76658845]
#      dataset  length_dataset   value_counts   roc_auc      aupr
# 0  cell-line              66  {0: 64, 1: 2}  0.195312  0.027493
# 0       TCGA              19  {1: 17, 0: 2}  0.941176  0.993272

# %%
model_CYCLOPHOSPHAMIDE.get_roc_pr_curves(best_parameters, False, 'tcga')

# %%
model_CYCLOPHOSPHAMIDE.get_train_set_results(best_parameters, False)
# Out:
# Threshold used for cell-line with CYCLOPHOSPHAMIDE: 0.49937833845615387
# Test set Idx 1 has only response []
#      dataset  length_dataset     value_counts   roc_auc      aupr
# 0  cell-line             579  {0: 561, 1: 18}  0.479897  0.044281
# 0        PDX               0               {}       NaN       NaN
# 0       TCGA              50    {1: 47, 0: 3}  0.936170  0.995931

# %%
model_CYCLOPHOSPHAMIDE.plot_confusion_matrix(best_parameters, False, 'tcga', 0.5)
# Out:
# Distribution of Predictions by Model
# [0.74969923 0.76011512 0.76188463 0.76561823 0.76658845]
# TP: 17, FP: 2, TN: 0, FN: 0

# %% [markdown]
# ## GEMCITABINE

# %%
best_parameters = {'audrc_threshold': 0.3998756676912308,
 'ldr': 0.412087327837944,
 'lr': 0.22698725104331968,
 'weight_decay': 0.02677728652954102,
 'momentum': 0.3792483150959015,
 'step_size': 15,
 'loss_weight_epic': 2.731753706932068,
 'loss_weight_epif': 4.4952181577682495,
 'loss_weight_epir': 1.3264448046684265,
 'loops_agg_warm': 90,
 'loops_train': 300,
 'loops_warm': 70,
 'ite_train_epi_c': 0,
 'ite_train_epi_f': 100,
 'hd': 3,
 'batch_size': 64,
 'warm_up_agg': 1,
 'test_every': 1,
 'bn_eval': 0,
 'seed': 42}

# %%
model_GEMCITABINE = ModelEpiFCR('GEMCITABINE', 'mutation')
#  Unable to calculate AUROC for validation set 1
model_GEMCITABINE.get_results(best_parameters)
# Out:
# DomainSpecificNN(
#   (feature1): FeatModule(
#     (features): Sequential(
#       (0): Linear(in_features=324, out_features=128, bias=True)
#       (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.412087327837944, inplace=False)
#       (4): Linear(in_features=128, out_features=128, bias=True)
#       (5): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (6): ReLU()
#       (7): Dropout(p=0.412087327837944, inplace=False)
#       (8): Linear(in_features=128, out_features=128, bias=True)
#       (9): Sigmoid()
#     )
#   )
#   (feature2): FeatModule(
#     (features): Sequential(
#       (0): Linear(in_features=324, out_features=128, bias=True)
#       (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.412087327837944, inplace=False)
#       (4): Linear(in_features=128, out_features=128, bias=True)
#       (5): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (6): ReLU()
#       (7): Dropout(p=0.412087327837944, inplace=False)
#       (8): Linear(in_features=128, out_features=128, bias=True)
#       (9): Sigmoid()
#     )
#   )
#   (classifier1): ClassifierModule(
#     (pred): Sequential(
#       (0): Linear(in_features=128, out_features=1, bias=True)
#     )
#   )
#   (classifier2): ClassifierModule(
#     (pred): Sequential(
#       (0): Linear(in_features=128, out_features=1, bias=True)
#     )
#   )
# )
# DomainAGG(
#   (feature): FeatModule(
#     (features): Sequential(
#       (0): Linear(in_features=324, out_features=128, bias=True)
#       (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.412087327837944, inplace=False)
#       (4): Linear(in_features=128, out_features=128, bias=True)
#       (5): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (6): ReLU()
#       (7): Dropout(p=0.412087327837944, inplace=False)
#       (8): Linear(in_features=128, out_features=128, bias=True)
#       (9): Sigmoid()
#     )
#   )
#   (classifier): ClassifierModule(
#     (pred): Sequential(
#       (0): Linear(in_features=128, out_features=1, bias=True)
#     )
#   )
#   (classifierrand): ClassifierModule(
#     (pred): Sequential(
#       (0): Linear(in_features=128, out_features=1, bias=True)
#     )
#   )
# )
# flags: {'audrc_threshold': 0.3998756676912308, 'ldr': 0.412087327837944, 'lr': 0.22698725104331968, 'weight_decay': 0.02677728652954102, 'momentum': 0.3792483150959015, 'step_size': 15, 'loss_weight_epic': 2.731753706932068, 'loss_weight_epif': 4.4952181577682495, 'loss_weight_epir': 1.3264448046684265, 'loops_agg_warm': 90, 'loops_train': 300, 'loops_warm': 70, 'ite_train_epi_c': 0, 'ite_train_epi_f': 100, 'hd': 3, 'batch_size': 64, 'warm_up_agg': 1, 'test_every': 1, 'bn_eval': 0, 'seed': 42}
# -------GEMCITABINE-------
# Threshold used for cell-line with GEMCITABINE: 0.3998756676912308
# cl train set size: 386
# tcga train set size: 35
# tcga validation set size: 9
# Threshold used for cell-line with GEMCITABINE: 0.3998756676912308
# cl test set size: 54
# pdx test set size: 0
# tcga test set size: 18
# Highest mean AUROC achieved during training: 0.5555555555555556
# Test set Idx 0 has only response [0]
# [0.1121422  0.20982663 0.24028943 0.26917674 0.31821327 0.44160387]
# PDX test set not available
# [0.20785338 0.25352847 0.26801335 0.29059029 0.30710767 0.36962318]
# /home/nicole/anaconda3/envs/druid/lib/python3.9/site-packages/sklearn/metrics/_ranking.py:877: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
#      dataset  length_dataset  value_counts   roc_auc      aupr
# 0  cell-line              54       {0: 54}       NaN -0.000000
# 0       TCGA              18  {0: 9, 1: 9}  0.851852  0.812654

# %%
model_GEMCITABINE.get_roc_pr_curves(best_parameters, False, 'tcga')

# %%
model_GEMCITABINE.get_train_set_results(best_parameters, False)
# Out:
# Threshold used for cell-line with GEMCITABINE: 0.3998756676912308
# Test set Idx 0 has only response [0]
# Test set Idx 1 has only response []
#      dataset  length_dataset    value_counts   roc_auc      aupr
# 0  cell-line             483        {0: 483}       NaN       NaN
# 0        PDX               0              {}       NaN       NaN
# 0       TCGA              44  {1: 27, 0: 17}  0.971678  0.981639

# %%
model_GEMCITABINE.plot_confusion_matrix(best_parameters, False, 'tcga', 0.5)
# Out:
# Distribution of Predictions by Model
# [0.20785338 0.26801335 0.29059029 0.30710767 0.36962318]
# TP: 0, FP: 0, TN: 9, FN: 9
